# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedAyman0/AhmedAyman0/blob/master/darknet_Yolo3_Pothole.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !wget https://srv-file14.gofile.io/download/8AsGlg/original.png
# Out:
# --2020-06-28 17:02:57--  https://srv-file14.gofile.io/download/8AsGlg/original.png
# Resolving srv-file14.gofile.io (srv-file14.gofile.io)... 178.170.41.149
# Connecting to srv-file14.gofile.io (srv-file14.gofile.io)|178.170.41.149|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 82 [text/html]
# Saving to: ‘original.png’
#
# original.png        100%[===================>]      82  --.-KB/s    in 0s
#
# 2020-06-28 17:02:58 (12.5 MB/s) - ‘original.png’ saved [82/82]

# %%
# %ls
# Out:
# gdrive/  sample_data/

# %%
# !unzip Pothole_YOLO.zip
# Out:
# Archive:  Pothole_YOLO.zip
#    creating: Pothole_YOLO/
#   inflating: Pothole_YOLO/.DS_Store
#   inflating: __MACOSX/Pothole_YOLO/._.DS_Store
#    creating: Pothole_YOLO/dataset/
#   inflating: __MACOSX/Pothole_YOLO/._dataset
#    creating: Pothole_YOLO/Data_Preperation/
#   inflating: Pothole_YOLO/pothole_yolov3_test.cfg
#   inflating: Pothole_YOLO/pothole_yolov3_train.cfg
#   inflating: Pothole_YOLO/dataset/img-110.txt
#   inflating: Pothole_YOLO/dataset/img-662.txt
#   inflating: Pothole_YOLO/dataset/img-104.txt
#   inflating: Pothole_YOLO/dataset/img-238.jpg
#   inflating: __MACOSX/Pothole_YOLO/dataset/._img-238.jpg
#   inflating: Pothole_YOLO/dataset/img-210.jpg
#   inflating: __MACOSX/Pothole_YOLO/dataset/._img-210.jpg
#   inflating: Pothole_YOLO/dataset/img-576.jpg
#   inflating: __MACOSX/Pothole_YOLO/dataset/._img-576.jpg
#   inflating: Pothole_YOLO/dataset/img-562.jpg
#   inflating: __MACOSX/Pothole_YOLO/dataset/._img-562.jpg
#   inflating: Pothole_YOLO/dataset/img-204.jpg
# ...

# %%
# %cd Pothole_YOLO/dataset/
# Out:
# /content/Pothole_YOLO/dataset

# %%
# %cd ../Data_Preperation/
# Out:
# /content/Pothole_YOLO/Data_Preperation

# %%
# !python3 creating-train-and-test-text-files.py

# %%
# !python3 creating-files-data-and-name.py

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# %cd ../
# Out:
# /content/Pothole_YOLO

# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 13778 (delta 0), reused 0 (delta 0), pack-reused 13775
# Receiving objects: 100% (13778/13778), 12.36 MiB | 8.64 MiB/s, done.
# Resolving deltas: 100% (9402/9402), done.

# %%
# %cd darknet
# Out:
# /content/Pothole_YOLO/darknet

# %%
# !make
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# !./darknet
# Out:
# /bin/bash: ./darknet: No such file or directory

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2020-06-18 15:08:24--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M   185KB/s    in 11m 31s
#
# 2020-06-18 15:19:57 (230 KB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !./darknet detector train labelled_data.data pothole_yolov3_train.cfg pothole_yolov3_train_1000.weights -map -dont_show
# Out:
# /bin/bash: ./darknet: No such file or directory

# %%
# !./darknet detector train labelled_data.data pothole_yolov3_train.cfg pothole_yolov3_train_3000.weights -map -dont_show
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  Prepare additional network for mAP calculation...
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...
